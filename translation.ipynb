# %% [markdown]
# <a href="https://colab.research.google.com/github/taniajasmin/Multilingual-Translator/blob/main/translation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install streamlit transformers torch
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.3/44.3 kB 870.6 kB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.7/9.7 MB 28.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 1.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 34.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 42.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 35.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 11.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 55.2 MB/s eta 0:00:00
# ...

# %%
# import streamlit as st
# from transformers import MarianMTModel, MarianTokenizer

# %%
# !pip install pyngrok

# %%
# from pyngrok import ngrok

# # Start Streamlit
# !streamlit run /usr/local/lib/python3.11/dist-packages/colab_kernel_launcher.py &>/dev/null&

# # Set up ngrok tunnel
# public_url = ngrok.connect(port='8501')
# print("Your Streamlit app is running at:", public_url)

# %%
from transformers import MarianMTModel, MarianTokenizer
import time

# %%
text = input("Enter the text you want to translate: ")
language_pair = input("Enter the language pair: ")

# Validate language pair input
while language_pair not in ["en-fr", "fr-en", "en-de", "de-en"]:
    print("Invalid language pair. Please enter a valid language pair (e.g., 'en-fr', 'fr-en', 'en-de', 'de-en').")
    language_pair = input("Enter the language pair: ")

# Load the model and tokenizer
tokenizer, model = load_model(language_pair)

# Translate the text
translated_text = translate_text(text, tokenizer, model)

# Show the output
print(f"\nOriginal Text: {text}")
print(f"Translated Text: {translated_text}")
# Out:
# Enter the text you want to translate: Hello!
# Enter the language pair: en-fr
#
# Original Text: Hello!
# Translated Text: Bonjour !

# %%
# # Function to load the translation model
# def load_model(language_pair):
#     model_name = f"Helsinki-NLP/opus-mt-{language_pair}"
#     tokenizer = MarianTokenizer.from_pretrained(model_name)
#     model = MarianMTModel.from_pretrained(model_name)
#     return tokenizer, model

# # Function to translate text
# def translate_text(text, tokenizer, model):
#     tokenized_text = tokenizer.prepare_seq2seq_batch([text], return_tensors="pt")
#     translated_tokens = model.generate(**tokenized_text)
#     translated_text = tokenizer.decode(translated_tokens[0], skip_special_tokens=True)
#     return translated_text

# %%
# Function to load the translation model
def load_model(language_pair):
    model_name = f"Helsinki-NLP/opus-mt-{language_pair}"
    tokenizer = MarianTokenizer.from_pretrained(model_name)
    model = MarianMTModel.from_pretrained(model_name)
    return tokenizer, model

# Function to translate text
def translate_text(text, tokenizer, model):
    tokenized_text = tokenizer.prepare_seq2seq_batch([text], return_tensors="pt")
    translated_tokens = model.generate(**tokenized_text)
    translated_text = tokenizer.decode(translated_tokens[0], skip_special_tokens=True)
    return translated_text

print("Available language pairs:")
print("1. en-fr (English to French)")
print("2. fr-en (French to English)")
print("3. en-de (English to German)")
print("4. de-en (German to English)")

# Get language pair selection from user
while True:
    try:
        choice = int(input("Enter the number of the language pair you want to use: "))
        if 1 <= choice <= 4:
            language_pair = ["en-fr", "fr-en", "en-de", "de-en"][choice - 1]
            break
        else:
            print("Invalid choice. Please enter a number between 1 and 4.")
    except ValueError:
        print("Invalid input. Please enter a number.")

# Get text input from user
text = input("Enter the text you want to translate: ")

# Load the model and tokenizer
tokenizer, model = load_model(language_pair)

# Translate the text
translated_text = translate_text(text, tokenizer, model)

# Output
print(f"\nOriginal Text: {text}")
print(f"Translated Text: {translated_text}")
# Out:
# Available language pairs:
# 1. en-fr (English to French)
# 2. fr-en (French to English)
# 3. en-de (English to German)
# 4. de-en (German to English)
# Enter the number of the language pair you want to use: 3
# Enter the text you want to translate: How is life?
# tokenizer_config.json:   0%|          | 0.00/42.0 [00:00<?, ?B/s]
# source.spm:   0%|          | 0.00/768k [00:00<?, ?B/s]
# target.spm:   0%|          | 0.00/797k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.27M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.33k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/298M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/298M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/293 [00:00<?, ?B/s]
# Original Text: How is life?
# Translated Text: Wie geht es dem Leben?

# %% [markdown]
# Adding more language

# %%
print("Available language pairs:")
print("1. en-fr (English to French)")
print("2. fr-en (French to English)")
print("3. en-de (English to German)")
print("4. de-en (German to English)")
print("5. en-es (English to Spanish)")
print("6. es-en (Spanish to English)")
print("7. en-it (English to Italian)")
print("8. it-en (Italian to English)")

# Update the language pair list
language_pairs = ["en-fr", "fr-en", "en-de", "de-en", "en-es", "es-en", "en-it", "it-en"]

# Get language pair selection from user
while True:
    try:
        choice = int(input("Enter the number of the language pair you want to use: "))
        if 1 <= choice <= len(language_pairs):
            language_pair = language_pairs[choice - 1]
            break
        else:
            print(f"Invalid choice. Please enter a number between 1 and {len(language_pairs)}.")
    except ValueError:
        print("Invalid input. Please enter a number.")


# Get text input from user
text = input("Enter the text you want to translate: ")

# Load the model and tokenizer
tokenizer, model = load_model(language_pair)

# Translate the text
translated_text = translate_text(text, tokenizer, model)

# Output
print(f"\nOriginal Text: {text}")
print(f"Translated Text: {translated_text}")
# Out:
# Available language pairs:
# 1. en-fr (English to French)
# 2. fr-en (French to English)
# 3. en-de (English to German)
# 4. de-en (German to English)
# 5. en-es (English to Spanish)
# 6. es-en (Spanish to English)
# 7. en-it (English to Italian)
# 8. it-en (Italian to English)
# Enter the number of the language pair you want to use: 7
# Enter the text you want to translate: Living is hopeless.
# tokenizer_config.json:   0%|          | 0.00/42.0 [00:00<?, ?B/s]
# source.spm:   0%|          | 0.00/789k [00:00<?, ?B/s]
# target.spm:   0%|          | 0.00/814k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/2.35M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.38k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/343M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/293 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/343M [00:00<?, ?B/s]
# Original Text: Living is hopeless.
# Translated Text: Vivere è senza speranza.

# %% [markdown]
# Adding Asian language

# %%
print("Available language pairs:")
print("1. en-fr (English to French)")
print("2. fr-en (French to English)")
print("3. en-de (English to German)")
print("4. de-en (German to English)")
print("5. en-es (English to Spanish)")
print("6. es-en (Spanish to English)")
print("7. en-ja (English to Japanese)")
print("8. ja-en (Japanese to English)")
print("9. en-ko (English to Korean)")
print("10. ko-cn (Korean to English)")
print("11. cn-zh (English to Simplified Chinese)")
print("12. zh-en (Simplified Chinese to English)")
print("13. tw-zh (English to Traditional Chinese)")
print("14. zh-tw (Traditional Chinese to English)")

# Chinese (Simplified): zh (or zh-cn for Simplified Chinese)

# Chinese (Traditional): zh-tw (for Traditional Chinese)

# Update the language pair list
language_pairs = [
    "en-fr", "fr-en", "en-de", "de-en", "en-es", "es-en",
    "en-ja", "ja-en", "en-ko", "ko-en", "en-zh", "zh-en"
]

# Get language pair selection from user
while True:
    try:
        choice = int(input("Enter the number of the language pair you want to use: "))
        if 1 <= choice <= len(language_pairs):
            language_pair = language_pairs[choice - 1]
            break
        else:
            print(f"Invalid choice. Please enter a number between 1 and {len(language_pairs)}.")
    except ValueError:
        print("Invalid input. Please enter a number.")
# Out:
# Available language pairs:
# 1. en-fr (English to French)
# 2. fr-en (French to English)
# 3. en-de (English to German)
# 4. de-en (German to English)
# 5. en-es (English to Spanish)
# 6. es-en (Spanish to English)
# 7. en-ja (English to Japanese)
# 8. ja-en (Japanese to English)
# 9. en-ko (English to Korean)
# 10. ko-cn (Korean to English)
# 11. cn-zh (English to Simplified Chinese)
# 12. zh-en (Simplified Chinese to English)
# 13. tw-zh (English to Traditional Chinese)
# 14. zh-tw (Traditional Chinese to English)
# Enter the number of the language pair you want to use: 11

# %%
# Language pair menu
print("Available language pairs:")
print("1. en-fr (English to French)")
print("2. fr-en (French to English)")
print("3. en-de (English to German)")
print("4. de-en (German to English)")
print("5. en-es (English to Spanish)")
print("6. es-en (Spanish to English)")
print("7. en-ja (English to Japanese)")
print("8. ja-en (Japanese to English)")
print("9. en-ko (English to Korean)")
print("10. ko-en (Korean to English)")
print("11. en-zh (English to Chinese)")
print("12. zh-en (Chinese to English)")

# Language pair list
language_pairs = [
    "en-fr", "fr-en", "en-de", "de-en", "en-es", "es-en",
    "en-ja", "ja-en", "en-ko", "ko-en", "en-zh", "zh-en"
]

# Get language pair selection from user
while True:
    try:
        choice = int(input("Enter the number of the language pair you want to use: "))
        if 1 <= choice <= len(language_pairs):
            language_pair = language_pairs[choice - 1]
            break
        else:
            print(f"Invalid choice. Please enter a number between 1 and {len(language_pairs)}.")
    except ValueError:
        print("Invalid input. Please enter a number.")

# Get text input from user
text = input("Enter the text you want to translate: ")

# Load the model and tokenizer
tokenizer, model = load_model(language_pair)

# Check if the model loaded successfully
if tokenizer is None or model is None:
    print("Failed to load the model. Please check your internet connection or try a different language pair.")
else:
    # Translate the text
    translated_text = translate_text(text, tokenizer, model)
    # Show the output
    print(f"\nOriginal Text: {text}")
    print(f"Translated Text: {translated_text}")
# Out:
# Available language pairs:
# 1. en-fr (English to French)
# 2. fr-en (French to English)
# 3. en-de (English to German)
# 4. de-en (German to English)
# 5. en-es (English to Spanish)
# 6. es-en (Spanish to English)
# 7. en-ja (English to Japanese)
# 8. ja-en (Japanese to English)
# 9. en-ko (English to Korean)
# 10. ko-en (Korean to English)
# 11. en-zh (English to Chinese)
# 12. zh-en (Chinese to English)
# Enter the number of the language pair you want to use: 7
# Enter the text you want to translate: Nice to meet you.
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_http.py in hf_raise_for_status(response, endpoint_name)
#     408     try:
# --> 409         response.raise_for_status()
#     410     except HTTPError as e:
#
# /usr/local/lib/python3.11/dist-packages/requests/models.py in raise_for_status(self)
# ...
